# %% [markdown]
# <a href="https://colab.research.google.com/github/zkfxhl/iot-class/blob/main/IOTlec_apartment_value.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

url = 'http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev'
params ={'serviceKey' : 'tChl36ZgGMWgTvwx9+D82p7bfH8ZbgVosc8QrRWHp4I+WfEReqJIp6WjgUFQzwPFVTi6sHDYMugrpBUDbrEJFQ==', 'pageNo' : '1', 'numOfRows' : '10', 'LAWD_CD' : '11410', 'DEAL_YMD' : '202401' }

response = requests.get(url, params=params)
print(response.text)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><거래금액>    53,000</거래금액><거래유형>중개거래</거래유형><건축년도>2004</건축년도><년>2024</년><도로명>서소문로</도로명><도로명건물본번호코드>00027</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11410</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>3005010</도로명코드><동> </동><등기일자> </등기일자><매도자>개인</매도자><매수자>개인</매수자><법정동> 충정로3가</법정동><법정동본번코드>0465</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11410</법정동시군구코드><법정동읍면동코드>10200</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>충정리시온</아파트><월>1</월><일>8</일><일련번호>11410-141</일련번호><전용면적>45.75</전용면적><중개사소재지>서울 서대문구</중개사소재지><지번>465</지번><지역코드>11410</지역코드><층>7</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    68,000</거래금액><거래유형>중개거래</거래유형><건축년도>2006</건축년도><년>2024</년><도로명>독립문로8길</도로명><도로명건물본번호코드>00054</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11410</도로명시군구코드><도로명일련번호코드>04</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4136063</도로명코드><동> </동><등기일자> </등기일자><매도자>개인</매도자><매수자>개인</매수자><법정동> 천연동</법정동><법정동본번코드>0145</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11410</법정동시군구코드><법정동읍면동코드>10600</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>천연뜨란채</아파트><월>1</월><일>10</일><일련번호>11410-3569</일련번호><전용면적>55.85</전용면적><중개사소재지>서울 서초구</중개사소재지><지번>145</지번><지역코드>11410</지역코드><층>3</층><해제사유발생일>24.01.17</해제사유발생일><해제여부>O</해제여부></item><item><거래금액>    79,000</거래금액><거래유형>중개거래</거래유형><건축년도>2006</건축년도><년>2024</년><도로명>독립문로8길</도로명><도로명건물본번호코드>00054</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11410</도로명시군구코드><도로명일련번호코드>04</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4136063</도로명코드><동> </동><등기일자> </등기일자><매도자>개인</매도자><매수자>개인</매수자><법정동> 천연동</법정동><법정동본번코드>0145</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11410</법정동시군구코드><법정동읍면동코드>10600</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>천연뜨란채</아파트><월>1</월><일>13</일><일련번호>11410-3569</일련번호><전용면적>56.08</전용면적><중개사소재지>서울 서대문구</중개사소재지><지번>145</지번><지역코드>11410</지역코드><층>15</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    80,000</거래금액><거래유형>중개거래</거래유형><건축년도>2006</건축년도><년>2024</년><도로명>독립문로8길</도로명><도로명건물본번호코드>00054</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11410</도로명시군구코드><도로명일련번호코드>04</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4136063</도로명코드><동> </동><등기일자> </등기일자><매도자>개인</매도자><매수자>개인</매수자><법정동> 천연동</법정동><법정동본번코드>0145</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11410</법정동시군구코드><법정동읍면동코드>10600</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>천연뜨란채</아파트><월>1</월><일>24</일><일련번호>11410-3569</일련번호><전용면적>56.08</전용면적><중개사소재지>서울 서대문구</중개사소재지><지번>145</지번><지역코드>11410</지역코드><층>10</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    85,000</거래금액><거래유형>직거래</거래유형><건축년도>1995</건축년도><년>2024</년><도로명>독립문로</도로명><도로명건물본번호코드>00010</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11410</도로명시군구코드><도로명일련번호코드>04</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>3112005</도로명코드><동> </동><등기일자> </등기일자><매도자>개인</매도자><매수자>개인</매수자><법정동> 영천동</법정동><법정동본번코드>0100</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11410</법정동시군구코드><법정동읍면동코드>10800</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>독립문삼호</아파트><월>1</월><일>6</일><일련번호>11410-9</일련번호><전용면적>84.78</전용면적><중개사소재지> </중개사소재지><지번>100</지번><지역코드>11410</지역코드><층>5</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    88,000</거래금액><거래유형>중개거래</거래유형><건축년도>1995</건축년도><년>2024</년><도로명>독립문로</도로명><도로명건물본번호코드>00010</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11410</도로명시군구코드><도로명일련번호코드>04</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>3112005</도로명코드><동> </동><등기일자> </등기일자><매도자>개인</매도자><매수자>개인</매수자><법정동> 영천동</법정동><법정동본번코드>0100</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11410</법정동시군구코드><법정동읍면동코드>10800</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>독립문삼호</아파트><월>1</월><일>28</일><일련번호>11410-9</일련번호><전용면적>75.66</전용면적><중개사소재지>서울 서대문구</중개사소재지><지번>100</지번><지역코드>11410</지역코드><층>13</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    63,900</거래금액><거래유형>중개거래</거래유형><건축년도>2000</건축년도><년>2024</년><도로명>통일로</도로명><도로명건물본번호코드>00279</도로명건물본번호코드><도로명건물부번호코드>00075</도로명건물부번호코드><도로명시군구코드>11410</도로명시군구코드><도로명일련번호코드>07</도로명일련번호코드><도로명지상지하코드>0</도로 ...

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(response.text, features="xml")

# %%
soup.find_all('거래금액')
# Out:
# [<거래금액>    53,000</거래금액>,
#  <거래금액>    68,000</거래금액>,
#  <거래금액>    79,000</거래금액>,
#  <거래금액>    80,000</거래금액>,
#  <거래금액>    85,000</거래금액>,
#  <거래금액>    88,000</거래금액>,
#  <거래금액>    63,900</거래금액>,
#  <거래금액>   122,000</거래금액>,
#  <거래금액>   133,500</거래금액>,
#  <거래금액>   155,000</거래금액>]
