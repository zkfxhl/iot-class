# %% [markdown]
# <a href="https://colab.research.google.com/github/zkfxhl/iot-class/blob/main/IOTlec_mqtt_thingspeak.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install paho-mqtt

# %%
import json
import requests
n=0

def doit(topic, payload):
  global n
  print(topic, payload)
  j=json.loads(payload)
  url='https://api.thingspeak.com/update?api_key=RRL0E2U7559SBMQQ'
  url +='&field1='+j['co2']
  url +='&field2='+j['bme680'].split(',')[0]
  if n>15:
    r=requests.get(url)
    print(url, r.text)
    n=0
  n+=1

# %%
import paho.mqtt.client as mqtt

def on_connect(client, userdata, flags, reason_code, properties):
    print(f"Connected with result code {reason_code}")
    client.subscribe("connectware/indoor/data/1501")

def on_message(client, userdata, msg):
    doit(msg.topic, msg.payload.decode('utf8'))

client = mqtt.Client(mqtt.CallbackAPIVersion.VERSION2)
client.on_connect = on_connect
client.on_message = on_message

client.connect("damoa.io", 1883, 60)
client.loop_forever()
# Out:
# Connected with result code Success
# connectware/indoor/data/1501 {"dust":"17,17","co2":"398","bme680":"24.67,31.04,942536,100991,27.93","time":"2024-04-05 00:28:36", "serial":32572, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"18,18","co2":"398","bme680":"24.67,31.04,943859,100990,27.93","time":"2024-04-05 00:28:37", "serial":32573, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"16,16","co2":"398","bme680":"24.67,31.05,943197,100989,28.10","time":"2024-04-05 00:28:38", "serial":32574, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"15,15","co2":"398","bme680":"24.67,31.05,941217,100988,28.01","time":"2024-04-05 00:28:39", "serial":32575, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"15,15","co2":"398","bme680":"24.67,31.05,949188,100988,28.01","time":"2024-04-05 00:28:40", "serial":32576, "ip":"203.255.190.49"}
# ...
