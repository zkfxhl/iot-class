# %% [markdown]
# <a href="https://colab.research.google.com/github/zkfxhl/iot-class/blob/main/IOTlec_mqttclient.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install paho-mqtt

# %%
import paho.mqtt.client as mqtt

def on_connect(client, userdata, flags, reason_code, properties):
    print(f"Connected with result code {reason_code}")
    client.subscribe("connectware/indoor/data/#")

def on_message(client, userdata, msg):
    print(msg.topic, msg.payload.decode('utf8'))

client = mqtt.Client(mqtt.CallbackAPIVersion.VERSION2)
client.on_connect = on_connect
client.on_message = on_message

client.connect("damoa.io", 1883, 60)
client.loop_forever()
# Out:
# Connected with result code Success
# connectware/indoor/data/1501 {"dust":"12,13","co2":"398","bme680":"24.85,31.39,937935,100986,28.26","time":"2024-04-04 23:36:01", "serial":29417, "ip":"203.255.190.49"}
# connectware/indoor/data/1502 {"dust":"14,15","co2":"484","bme680":"26.38,28.44,1648079,101034,24.17","time":"2024-04-04 23:36:01", "serial":24858, "ip":"203.255.190.49"}
# connectware/indoor/data/1503 {"dust":"7,8","co2":"380","bme680":"25.60,30.37,735698,100992,27.76","time":"2024-04-04 23:36:02", "serial":24866, "ip":"203.255.190.49"}
# connectware/indoor/data/1501 {"dust":"12,13","co2":"398","bme680":"24.85,31.38,940559,100986,28.26","time":"2024-04-04 23:36:02", "serial":29418, "ip":"203.255.190.49"}
# connectware/indoor/data/1502 {"dust":"14,15","co2":"484","bme680":"26.38,28.44,1646039,101034,24.26","time":"2024-04-04 23:36:02", "serial":24859, "ip":"203.255.190.49"}
# ...
